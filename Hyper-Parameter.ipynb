# %% [markdown]
# # Hyperparameter Optimization for Predicting Heart Desease Condition
#
# #### Hyperparameter Optimization (Validation, Cross-Validation, Pipeline, and Grid Search)
# ___
# ## Setup
#  The data on heart disease can be found [here](#https://www.kaggle.com/datasets/cherngs/heart-disease-cleveland-uci).

# %% [markdown]
# ## Table of Contents
#
# * [Data Dictionary](#data-dictionary)
# * [Data Loading](#data-loading)
# * [Optimization Using only One Validation Set](#optimization-using-only-one-validation-set)
# * [Optimization Using Cross-Validation](#optimization-using-cross-validation)
# * [Optimization Using Pipeline and Grid Search](#optimizing-using-pipeline-and-grid-search)
# * [Conclusions and Common Questions](#conclusions-and-common-questions)

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# | **Feature**  | **Description**                                                                                                                                                                                                                             |
# |----------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Age      | age in years                                                                                                                                                                                                                            |
# | Sex      | 1 = male; 0 = female                                                                                                                                                                                                                    |
# | cp       | Chest pain type: 0 = typical angina, 1 = atypical angina, 2 = non-anginal pain, Value 3: asymptomatic                                                                                                                                   |
# | trestbps | resting blood pressure (in mm Hg on admission to the hospital)                                                                                                                                                                          |
# | chol     | serum cholestoral in mg/dl                                                                                                                                                                                                              |
# | fbs      | fasting blood sugar > 120 mg/dl: 1 = true; 0 = false                                                                                                                                                                                    |
# | restecg  | resting electrocardiographic results: 0 = normal, 1 = having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria |
# | thalach  | maximum heart rate achieved                                                                                                                                                                                                             |
# | exang    | exercise induced angina: 1 = yes; 0 = no                                                                                                                                                                                                |
# | oldpeak  | ST depression induced by exercise relative to rest                                                                                                                                                                                      |
# | slope    | the slope of the peak exercise ST segment: 0 = upsloping, 1 = flat, 2 = downsloping                                                                                                                                                     |
# | ca       | number of major vessels (0-3) colored by flourosopy                                                                                                                                                                                     |
# | thal     | 0 = normal; 1 = fixed defect; 2 = reversable defect and the label                                                                                                                                                                       |

# %% [markdown]
# | **Target**  | **Description**                                                                                                                                                                                                                             |
# |----------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Condition      | 0 = no disease, 1 = disease

# %% [markdown]
# ## Data Loading

# %%
# Basic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# To split the data as necessary for modelling
from sklearn.model_selection import train_test_split

# To build a simple model
from sklearn.linear_model import LogisticRegression

# To get rid of logistic regression default solver warnings that appear if sklearn hasn't been updated
import warnings
warnings.filterwarnings('ignore')

# To "pickle" things, like accuracies or even an entire fitted model
import joblib

# To cross-validate
from sklearn.model_selection import cross_val_score

# To set up a temporary directory for caching pipeline results
from tempfile import mkdtemp

# To build a pipeline
from sklearn.pipeline import Pipeline

# To try scaling the data in various ways
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# To try dimensionality reduction
from sklearn.decomposition import PCA

# To do a cross-validated grid search
from sklearn.model_selection import GridSearchCV

# %%
# Read the data into a dataframe
df = pd.read_csv('data/heart.csv')

# Take a look at the data
display(df)

# Any nulls?
print(f'There are {df.isna().sum().sum()} null values.')
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     69    1   0       160   234    1        2      131      0      0.1
# 1     69    0   0       140   239    0        0      151      0      1.8
# 2     66    0   0       150   226    0        0      114      0      2.6
# 3     65    1   0       138   282    1        2      174      0      1.4
# 4     64    1   0       110   211    0        2      144      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 0        1   1     0          0
# 1        0   2     0          0
# 2        2   0     0          0
# 3        1   1     0          1
# 4        1   0     0          0
# ..     ...  ..   ...        ...
# 292      0   0     2          1
# 293      1   0     2          1
# 294      1   0     2          1
# 295      0   0     0          0
# 296      0   0     2          1
#
# [297 rows x 14 columns]
# There are 0 null values.

# %%
# Check class counts
df['condition'].value_counts()
# Out:
# 0    160
# 1    137
# Name: condition, dtype: int64

# %%
# Check class proportions
df['condition'].value_counts(normalize=True)
# Out:
# 0    0.538721
# 1    0.461279
# Name: condition, dtype: float64

# %% [markdown]
# Things to note:
# - The columns contain various health-related data.
# - Each row corresponds to a patient.
# - The target is either 1 (has heart disease) or 0 (does not have heart disease), so this will be a binary classification problem.
# - The classes are fairly well-balanced. Ideally we'd do far more EDA, but we'll skip that for now.

# %%
# Set up X (i.e., independent variables; features) and y (i.e., dependent variable; target)
X = df.drop('condition', axis=1)
y = df['condition']

# Print shapes
print('Shape of X:', X.shape)
print('Shape of y:', y.shape)
# Out:
# Shape of X: (297, 13)
# Shape of y: (297,)

# %% [markdown]
# ___
# ## Optimization Using only One Validation Set
# When we first learned about hyperparameter optimization, we used `train_test_split` twice. We first split the data into a remainder set and a test set, like so:

# %%
# Split the data into remainder and test sets
X_rem, X_test, y_rem, y_test = train_test_split(X, y, test_size=0.3, random_state=22, stratify=y)

# Print info on how the data has been split
print(f'The remainder set has {len(X_rem)} data points.')
print(f'The test set has {len(X_test)} data points.')
# Out:
# The remainder set has 207 data points.
# The test set has 90 data points.

# %% [markdown]
# Some things to note here:
# - There is no test size that is perfect for any dataset; you'll have to consider how many data points you have in total and make a suitable decision. That being said, 0.3 is usually a safe choice.
# - Why use the `random_state` parameter?
#     - When using `train_test_split()`, the data points get shuffled by default and distributed randomly to the two resulting sets. Using the `random_state` parameter ensures we get reproducible results no matter where or how many times we run our cells.
#     - This is found in many other Scikit-learn functions, and you'll see this parameter being used often.
#     - You can pass in any integer.
# - Why use the `stratify` parameter?
#     - We want the original class proportions (in `y`, in this case) to be preserved as closely as possible in each of the two resulting sets, and this parameter ensures that.
#     - This is more important to use when dealing with imbalanced data. For an extremely imbalanced dataset, not using this parameter could result in the minority class not being included at all in one of the two sets.
#     - This is just a safe choice for any classification task regardless of the class distribution you're dealing with.
#
# Before we try to optimize hyperparameters using a validation set, let's try building a baseline model and see how it performs.

# %%
# Baseline logistic regression
# Instantiate and fit to the remainder set
baseline_logreg = LogisticRegression(random_state=1).fit(X_rem, y_rem)

# Print the accuracies
print(f'Accuracy on remainder set: {baseline_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {baseline_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8444444444444444

# %% [markdown]
# We'll keep these accuracies in mind for later.
#
# We then set the test set aside and split the remainder set into a train set and a validation set, like so:

# %%
# Split the remainder set into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_rem, y_rem, test_size=0.2, random_state=22, stratify=y_rem)

# Print info on how the data has been split
print(f'The train set has {len(X_train)} data points.')
print(f'The validation set has {len(X_val)} data points.')
# Out:
# The train set has 165 data points.
# The validation set has 42 data points.

# %% [markdown]
# More things to note:
# - Again, there is no *ideal* size to use, but 0.2 seems appropriate. There is no need to make your test and validation sets the same size.
# - This time we stratify according to `y_rem` instead of `y`.
#
# We can check that the class proportions have been preserved in all sets.

# %%
print('Proportions in original data:')
print(y.value_counts(normalize=True), '\n')

print('Proportions in remainder set:')
print(y_rem.value_counts(normalize=True), '\n')

print('Proportions in test set:')
print(y_test.value_counts(normalize=True), '\n')

print('Proportions in train set:')
print(y_train.value_counts(normalize=True), '\n')

print('Proportions in validation set:')
print(y_val.value_counts(normalize=True), '\n')
# Out:
# Proportions in original data:
# 0    0.538721
# 1    0.461279
# Name: condition, dtype: float64
#
# Proportions in remainder set:
# 0    0.541063
# 1    0.458937
# Name: condition, dtype: float64
#
# Proportions in test set:
# 0    0.533333
# 1    0.466667
# Name: condition, dtype: float64
#
# Proportions in train set:
# 0    0.539394
# 1    0.460606
# Name: condition, dtype: float64
#
# Proportions in validation set:
# 0    0.547619
# 1    0.452381
# Name: condition, dtype: float64

# %% [markdown]
# It appears that the proportions have been preserved. Some of them could not be kept exactly the same just due to a limited availability of data points, but they are close enough.
#
# At this point we could try fitting a scaler and/or PCA to the train set and then transforming the train and validation sets, but we'll skip that for now. Note that if we were to do this, we would have many different models to compare (grid search will come in handy for this later).
#
# Let's try a simple hyperparameter optimization. We'll try varying the regularization strength (l2 in this case, since this is the default penalty for logistic regression in Scikit-learn).

# %% [markdown]
# ### Manually Optimizing for C in Logistic Regression

# %%
# Let's try a modest range of C values
c_values = [.00001, .0001, .001, .1, 1, 10, 100, 1000, 10000]

# Set up empty lists
train_accuracies = []
validation_accuracies = []

# Iterate over the C values
for value in c_values:
    
    # Instantiate a log reg and fit to the train set
    logreg = LogisticRegression(C=value, random_state=1).fit(X_train, y_train)
    
    # Score on the train set and append this accuracy to its respective list
    train_accuracies.append(logreg.score(X_train, y_train))
    
    # Score on the validation set and append this accuracy to its respective list
    validation_accuracies.append(logreg.score(X_val, y_val))

# %%
# Check the accuracies
pd.DataFrame({'C value': c_values, 'train accuracy': train_accuracies, 'validation accuracy': validation_accuracies})
# Out:
#        C value  train accuracy  validation accuracy
# 0      0.00001        0.654545             0.547619
# 1      0.00010        0.733333             0.571429
# 2      0.00100        0.757576             0.595238
# 3      0.10000        0.866667             0.833333
# 4      1.00000        0.872727             0.857143
# 5     10.00000        0.872727             0.833333
# 6    100.00000        0.872727             0.857143
# 7   1000.00000        0.866667             0.833333
# 8  10000.00000        0.872727             0.857143

# %%
# Plot the accuracies
plt.figure(figsize=(10, 5))
plt.plot(c_values, train_accuracies, label='Train', marker='.')
plt.plot(c_values, validation_accuracies, label='Validation', marker='.')
plt.legend()
plt.title('Effect of Varying C on Logistic Regression Accuracies')
plt.xscale('log') # Put the x-axis on a log scale; this is important because the C values vary in orders of magnitude
plt.xlabel('C')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

# %% [markdown]
# We pick a value of C that yields the highest validation accuracy without the train accuracy being too high (which would indicate overfitting). Based on the above, let's choose a C value of 100, build a final model, and score on the remainder and test sets. **Don't forget this step!**

# %%
# Instantiate a log reg and fit to the remainder set
validated_logreg = LogisticRegression(C=100, random_state=1).fit(X_rem, y_rem)

# Print the accuracies
print(f'Accuracy on remainder set: {validated_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {validated_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8599033816425121
# Accuracy on test set: 0.8666666666666667

# %%
# Reminder: baseline accuracies from before
print(f'Accuracy on remainder set: {baseline_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {baseline_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8444444444444444

# %% [markdown]
# Note that the remainder accuracy after doing one validation is actually lower than that of the baseline model (although pretty close). What happened? Isn't hyperparameter optimization supposed to lead to the best accuracies? What about the test accuracy?
#
# The *best* hyperparameter we found, which C = 100, did result in one of the best *validation* accuracies; I also selected a value of C != 1 because that is the default value and I wanted our model to be different to our baseline. However, there was no guarantee that this would result in the best *test* accuracy.
#
# Another thing to note: test accuracy is usually more important than remainder accuracy. After all, we want our models to perform well on *unseen* data. The higher test accuracy (coupled with the fact that it is higher than the remainder accuracy) could be chance due to the way the sets were created.
#
# In the hyperparameter optimization lecture, you then learned that the optimal hyperparameter we pick can vary depending on what data points were randomly included in the validation set, so the better option is to use cross-validation instead. So why would we ever do just one validation? This is because cross-validation is more computationally expensive than just validating once, and it's better to try validating at least once than not at all. If we were to pick an optimal hyperparameter using the test set, we would be peeking into data that the model was never supposed to see, hence *cheating*.

# %% [markdown]
# ___
# ## Optimization Using Cross-Validation
# Ideally we should always cross-validate when we want to optimize hyperparameters. When using cross-validation, we no longer need to split our data twice; that is, we can just pass in our remainder set, and the cross-validation function will automatically split the remainder set into train and validation sets in *k* different ways (_i.e._, folds).
#
# The diagram below shows a 5-fold cross-validation. Each circle represents a data point, and the colours represent different classes. Notice that each data point (aside from those in the test set) gets to be in a validation set only once.
#
# <img src = "https://scikit-learn.org/stable/_images/grid_search_cross_validation.png" width = 800>
#
# When we do the single `train_test_split()` that is required for cross-validation (or for a grid search, as you'll see later), we no longer have to call our resulting sets the "remainder" and "test" sets. We can go back to calling them "train" and "test" sets if we want (and also name the variables accordingly), and then in cross-validation, the train set automatically gets split into *k* different *smaller* "train" and "validation" sets. This can get confusing, so if you still want to call them "remainder" and "test" sets, go ahead! Use whichever variable names that help your understanding. Note that in the pipeline lecture and for the preprocessed datasets that were sent out for NLP part 2, the sets were named "train" and "test".
#
# With that said, let's now try 5-fold cross-validation. I will add some things that help us keep track of the progress, and explain them below.

# %%
# %%time

# This is the same range of C values that I used before
c_values = [.00001, .0001, .001, .1, 1, 10, 100, 1000, 10000]

# Set up an empty list
cv_accuracies = []

# Iterate over the C values
for value in c_values:
    
    # Instantiate a log reg
    logreg = LogisticRegression(C=value, random_state=1, n_jobs=-1, max_iter=10000)
    
    # Pass the model and the remainder set into the cross-validation function, then get cross-validated accuracy by taking the mean
    cv_accuracy = np.mean(cross_val_score(logreg, X_rem, y_rem, cv=5, n_jobs=-1))
    
    # Append the cross-validated accuracy to the list set up above
    cv_accuracies.append(cv_accuracy)
    
    # Dump the updated list of accuracies into a .pkl file
    joblib.dump(cv_accuracies, 'data/pickles/pickled_cv_accuracies.pkl')
    
    # Print something at the end of each iteration
    print(f'For a C value of {value}, the cross-validated accuracy is {round(cv_accuracy, 6)}')
# Out:
# For a C value of 1e-05, the cross-validated accuracy is 0.594774
# For a C value of 0.0001, the cross-validated accuracy is 0.6964
# For a C value of 0.001, the cross-validated accuracy is 0.744715
# For a C value of 0.1, the cross-validated accuracy is 0.840302
# For a C value of 1, the cross-validated accuracy is 0.820906
# For a C value of 10, the cross-validated accuracy is 0.820906
# For a C value of 100, the cross-validated accuracy is 0.816144
# For a C value of 1000, the cross-validated accuracy is 0.816144
# For a C value of 10000, the cross-validated accuracy is 0.816144

# %% [markdown]
# Several things to note here:
# - The `cross_val_score()` function checks if you are doing a classification task, and if so, uses `StratifiedKFold()` by default. Just like when I talked about `stratify` earlier, this ensures that class proportions are preserved in all the train and validation sets in the folds. You can read more about this in the documentation:
#     - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
#     - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html
# - The `cv` parameter refers to how many folds you want in your cross-validation. The default is 3 in this version of Scikit-learn, but this has been changed to 5 in newer versions. We manually set it to 5 here because we want five folds.
#     - Like many other aspects of machine learning, the number of folds we choose is somewhat arbitrary. Five is conventional, and in each fold, 80% of the data is used for training and 20% is used for validation.
# - The `cross_val_score` function returns 5 scores (or whatever number you set for `cv`). We then take the mean of these 5 scores, and this mean is what the cross-validated score actually is.
#
# Keeping track of progress and speeding things up:
# - Passing in `%%time` at the top of a cell will return how long it took for the whole cell to be run. Note that this has to be at the very top, and not even comments can be placed before it.
# - Adding a simple print statement in the for loop is an easy way for us to keep track of the iterations.
# - We can pass in `n_jobs=-1` to `LogisticRegression()` and `cross_val_score()` to use as many CPU cores as possible.
# - We can pickle the accuracies using the joblib package. This way, even if the loop were to end prematurely for whatever reason, we can save some of the results and use them later.
# - You can also try tweaking the `verbose` parameter in `cross_val_score()`. This parameter is also available in `GridSearchCV()`, which I'll showcase later.
# - These things are more useful when working with a lot more data. They aren't necessary for the small dataset we're working with, but they're good to know! They can be done for one validation as well.
#
# We can load in the pickled accuracies here or in any other notebook to work with.

# %%
# Load
pickled_cv_accuracies = joblib.load('data/pickles/pickled_cv_accuracies.pkl')

# Check
pickled_cv_accuracies
# Out:
# [0.5947735191637631,
#  0.6963995354239257,
#  0.7447154471544716,
#  0.8403019744483158,
#  0.8209059233449476,
#  0.8209059233449476,
#  0.8161440185830429,
#  0.8161440185830429,
#  0.8161440185830429]

# %%
# Sanity check
cv_accuracies == pickled_cv_accuracies
# Out:
# True

# %%
# Plot the accuracies
plt.figure(figsize=(10, 5))
plt.plot(c_values, cv_accuracies, marker = '.')
plt.title('Effect of Varying C on Cross-Validated Logistic Regression Accuracies')
plt.xscale('log') # Put the x-axis on a log scale; this is important because the C values vary in orders of magnitude
plt.xlabel('C')
plt.ylabel('Cross-Validated Accuracy')
plt.grid()
plt.show()

# %% [markdown]
# The downside of cross-validation is that we can't plot the train accuracies, but theoretically, cross-validation should combat overfitting.
#
# Based on the above, let's choose a C value of 0.1, build a final model, and score on the remainder and test sets. **Don't forget this step!**

# %%
# Instantiate a log reg and fit on the remainder set
cv_logreg = LogisticRegression(C=0.1, random_state=1).fit(X_rem, y_rem)

# Print the accuracies
print(f'Accuracy on remainder set: {cv_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {cv_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8222222222222222

# %%
# Reminder: baseline accuracies from before
print(f'Accuracy on remainder set: {baseline_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {baseline_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8444444444444444

# %%
# Reminder: one-validation accuracies from before
print(f'Accuracy on remainder set: {validated_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {validated_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8599033816425121
# Accuracy on test set: 0.8666666666666667

# %% [markdown]
# - The test accuracy after using cross-validation is lower than the one from our baseline model, which once again shows that doing hyperparameter optimization doesn't guarantee we'll get better results, although it's still a good thing to do.
#
# Another downside of using cross-validation is that it becomes much harder to try scaling or PCA, since we would have to manually do so on each of the *k* folds (that's a lot of repetitive work). This is where pipeline and grid search come in handy.

# %% [markdown]
# ___
# ## Optimizing Using Pipeline and Grid Search
# Pipelines and grid searches take a lot of care to set up properly, but once they're set up, they allow us to do an exhaustive search over many different hyperparameters and evaluators.

# %%
# Set up a directory to cache the pipeline results
cachedir = mkdtemp()

# Set up a pipeline
# The steps here act as placeholders and will be changed when we pass the pipeline into the grid search later
my_pipeline = Pipeline([('scaler', StandardScaler()), 
                        ('dim_reducer', PCA()), 
                        ('model', LogisticRegression())], memory=cachedir)

# %% [markdown]
# Some things to note:
# - We pass in the steps (_i.e._, the placeholder evaluators) as a list of tuples. Here we have a list of 3 tuples.
#     - In each tuple, the first element is the name we give for the evaluator, and the second element is the evaluator itself.
# - We can use the `memory` parameter to cache results. This helps speed up computation.
#
# Now let's set up our parameter grid so we can try several estimators and hyperparameters:
# - No scaler, standard scaler, min-max scaler, and robust scaler
# - No PCA, and PCA with some different numbers of components
# - Logistic regression with l1 and l2 regularizations (penalties), and with a range of regularization strengths (C values)

# %%
# Let's try the same range of C values from earlier
c_values = [.00001, .0001, .001, .1, 1, 10, 100, 1000, 10000]

# Parameter grid
logreg_param_grid = [
    
    # l1 without PCA
    {'scaler': [None, StandardScaler(), MinMaxScaler(), RobustScaler()],
     'dim_reducer': [None],
     'model': [LogisticRegression(penalty='l1', random_state=1, n_jobs=-1, max_iter=10000)],
     'model__C': c_values},
    
    # l1 with PCA
    {'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
     'dim_reducer': [PCA()],
     'dim_reducer__n_components': [0.95, 0.9, 0.85, 0.8],
     'model': [LogisticRegression(penalty='l1', random_state=1, n_jobs=-1, max_iter=10000)],
     'model__C': c_values},
    
    # l2 (default) without PCA
    {'scaler': [None, StandardScaler(), MinMaxScaler(), RobustScaler()],
     'dim_reducer': [None],
     'model': [LogisticRegression(solver='lbfgs', random_state=1, n_jobs=-1, max_iter=10000)],
     'model__C': c_values},
    
    # l2 (default) with PCA
    {'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
     'dim_reducer': [PCA()],
     'dim_reducer__n_components': [0.95, 0.9, 0.85, 0.8],
     'model': [LogisticRegression(solver='lbfgs', random_state=1, n_jobs=-1, max_iter=10000)],
     'model__C': c_values}
]

# %% [markdown]
# Why didn't I do this?
# ```python
# # Log reg
# {'scaler': [StandardScaler(), MinMaxScaler(), RobustScaler()],
#  'dim_reducer': [None, PCA()],
#  'dim_reducer__n_components': [0.95, 0.9, 0.85, 0.8],
#  'model': [LogisticRegression(random_state=1, n_jobs=-1)],
#  'model__penalty': ['l1', 'l2'],
#  'model__C': c_values}
# ```
# - Trying various `n_components` isn't compatible with not using PCA.
# - `lbfgs` isn't compatible with l1 penalty.

# %% [markdown]
# Several things to note:
# - A parameter grid is a big list of dictionaries. Each dictionary can have several key-value pairs.
#     - The keys are the evaluator names we set up in the pipeline object earlier, or the hyperparameters we want to tune. To refer to a hyperparameter, we have to type two underscores between the evaluator name and the hyperparameter. The syntax can be confusing and easy to mess up, so we have to pay close attention to get everything just right.
# - I like to set up a parameter grid and grid search for each model type. For example, in my capstone, I had a setup for logistic regression, another for SVM, another for KNN, and so on. I find that this helps me keep track of how each type performs. If you make an enormous parameter grid with multiple model types, the grid search would take longer and it would be hard to tell which type is holding the entire search back.
# - During the PCA lecture, we plotted `explained_variance_ratio_` to decide how many principal components to use. Although this was excellent for our understanding, a more convenient way when we tune this in a grid search is to pass in a float between 0 and 1 for the `n_components` parameter.
#     - For example, if we pass in 0.95, the algorithm will automatically pick enough components to explain at least 95% of the variance.
# - In Scikit-learn, the default penalty for logistic regression is l2.
#     - `lbfgs` is a solver that is only available for l2 logistic regression. It is quicker for large datasets and is the default in newer versions of Scikit-learn.
#
# We can now instantiate a cross-validated grid search and fit it to our remainder set. We can pass in our familiar `cv=5` for 5-fold cross-validation, and `n_jobs=-1` to use all CPU cores. There is also the `verbose` parameter that we can tweak to see some outputs on the progress.
#
# This is what happens if we set `verbose` to 0 (default):

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=0)

# Fit the log reg grid search
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)

# %% [markdown]
# ___
# This is what happens if we set `verbose` to 1:

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=1)

# Fit the log reg grid search
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits

# %% [markdown]
# ___
# This is what happens if we set `verbose` to 5:

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=5)

# Fit the log reg grid search
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=None;, score=nan total time=   0.0s[CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=None;, score=nan total time=   0.0s
#
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=None;, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=None;, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=None;, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=None;, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=None;, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=None;, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=None;, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=100, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.1, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10, scaler=StandardScaler();, score=nan total time=   0.0s
# ...
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.905 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s[CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
#
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hd/c186n5_n3bz2nkrqf2gqjwlw0000gp/T/ipykernel_81490/3865325217.py in <module>
#       3
#       4 # Fit the log reg grid search
# ----> 5 fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     439                     return self.__get_result()
#     440
# --> 441                 self._condition.wait(timeout)
#     442
#     443                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ___
# This is what happens if we set `verbose` to 10:

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=10)

# Fit the log reg grid search (this is what takes long)
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.707 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.732 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.756 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.0001, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.810 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=None;, score=0.881 total time=   0.1s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=None;, score=0.810 total time=   0.1s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=None;, score=0.780 total time=   0.1s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=None;, score=0.805 total time=   0.1s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=None;, score=0.805 total time=   0.1s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.810 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.810 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.810 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.707 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.732 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.619 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=None;, score=0.667 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=None;, score=0.571 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=None;, score=0.659 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=None;, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=None;, score=0.780 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.756 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# ...
# [CV 3/5; 176/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 3/5; 176/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 176/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 4/5; 176/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 176/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 5/5; 176/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 5/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 1/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 1/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 2/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 3/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 4/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 5/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 1/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 1/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 2/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 3/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 4/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 5/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 1/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 2/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 3/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 4/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 5/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 1/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 2/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 3/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 4/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 5/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 2/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 3/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 260/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 260/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 261/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()

# %% [markdown]
# ___
# This is what happens if we set `verbose` to 11 (the outputs start to get overwhelming):

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=11)

# Fit the log reg grid search (this is what takes long)
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 5/5; 201/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 5/5; 201/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 202/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 1/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 202/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 2/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 202/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 3/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 2/5; 228/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 2/5; 228/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 228/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 3/5; 228/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 228/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 4/5; 228/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 228/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 5/5; 228/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 229/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 1/5; 229/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 229/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 2/5; 229/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 229/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 3/5; 229/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 229/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 4/5; 229/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 229/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 5/5; 229/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 230/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 1/5; 230/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 230/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 2/5; 230/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 230/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 3/5; 230/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 230/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 4/5; 230/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 230/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 5/5; 230/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 231/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 1/5; 231/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 231/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 2/5; 231/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 231/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 3/5; 231/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 231/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 4/5; 231/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 231/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 5/5; 231/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 3/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 4/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 3/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 1/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 2/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 5/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 5/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 205/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 205/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 205/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 206/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 206/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 206/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 206/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 206/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 3/5; 206/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 206/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 206/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 206/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 206/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 1/5; 207/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 207/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 207/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 207/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 207/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 207/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.756 total time=   0.0s
# [CV 4/5; 207/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 207/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 207/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 5/5; 207/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 208/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 1/5; 208/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 208/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 208/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 208/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 208/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 208/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 208/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 208/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 208/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 247/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 3/5; 247/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 247/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 4/5; 247/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 247/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 5/5; 247/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 248/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 1/5; 248/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 248/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 2/5; 248/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 248/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 3/5; 248/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 248/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 4/5; 248/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 248/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 5/5; 248/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.902 total time=   0.0s
# [CV 1/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 1/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 2/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 3/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 1/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 2/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 3/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 4/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 5/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 1/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 4/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 5/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 1/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 2/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 2/5; 181/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 181/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 181/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 181/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 181/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 181/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 181/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 182/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 1/5; 182/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 182/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 2/5; 182/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 182/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 3/5; 182/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 182/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 4/5; 182/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 182/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 5/5; 182/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 183/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 1/5; 183/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 183/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 183/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 1/5; 241/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 1/5; 241/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 2/5; 241/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 2/5; 241/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.714 total time=   0.0s
# [CV 3/5; 241/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 3/5; 241/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.707 total time=   0.0s
# [CV 4/5; 241/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 4/5; 241/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.732 total time=   0.0s
# [CV 5/5; 241/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 5/5; 241/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 242/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 1/5; 242/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 242/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 2/5; 242/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 242/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 3/5; 242/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 242/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 4/5; 242/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 242/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 5/5; 242/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 243/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 1/5; 243/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.619 total time=   0.0s
# [CV 2/5; 243/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 2/5; 243/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 3/5; 243/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 3/5; 243/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 243/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 4/5; 243/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 5/5; 243/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 5/5; 243/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 1/5; 244/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 1/5; 244/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 244/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 2/5; 244/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5; 244/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 3/5; 244/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 244/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 4/5; 244/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 244/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 5/5; 244/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 245/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 1/5; 245/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 245/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 2/5; 245/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 245/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 3/5; 245/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 4/5; 245/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 4/5; 245/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 245/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 5/5; 245/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 246/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 1/5; 246/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 246/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 2/5; 246/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 246/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 3/5; 246/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 246/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# ...
# [CV 5/5; 114/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5; 115/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 115/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5; 115/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 115/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5; 115/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 3/5; 115/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5; 115/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 4/5; 115/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5; 115/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 115/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5; 116/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 116/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5; 116/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 116/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/5; 116/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 3/5; 116/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/5; 116/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 116/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 5/5; 116/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 116/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/5; 117/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 117/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 2/5; 117/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 117/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5; 117/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 117/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 4/5; 117/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 117/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 5/5; 117/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 5/5; 117/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=10000, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 1/5; 118/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 1/5; 118/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5; 118/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 118/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 3/5; 118/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 118/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 4/5; 118/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 118/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 5/5; 118/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 118/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 1/5; 119/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 1/5; 119/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5; 119/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 2/5; 119/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/5; 164/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 2/5; 164/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 164/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 3/5; 164/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 164/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 164/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 164/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 164/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 165/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None
# [CV 1/5; 165/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None;, score=0.881 total time=   0.1s
# [CV 2/5; 165/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None
# [CV 2/5; 165/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None;, score=0.833 total time=   0.1s
# [CV 3/5; 165/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None
# [CV 3/5; 165/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None;, score=0.780 total time=   0.0s
# [CV 4/5; 165/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None
# [CV 4/5; 165/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None;, score=0.805 total time=   0.1s
# [CV 5/5; 165/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None
# [CV 5/5; 165/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=None;, score=0.805 total time=   0.1s
# [CV 1/5; 166/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 1/5; 166/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 166/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 2/5; 166/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 3/5; 166/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 3/5; 166/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 166/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 4/5; 166/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 166/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 5/5; 166/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 167/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 1/5; 167/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 167/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 167/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 3/5; 167/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 167/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 167/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 4/5; 167/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 167/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 5/5; 167/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 168/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()

# %% [markdown]
# ___
# This is what happens if we set `verbose` to 100 **(this is very impractical; don't do this)**:

# %%
# Instantiate the log reg grid search
logreg_gs = GridSearchCV(my_pipeline, param_grid=logreg_param_grid, cv=5, n_jobs=-1, verbose=100)

# Fit the log reg grid search (this is what takes long)
fitted_logreg_gs = logreg_gs.fit(X_rem, y_rem)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 5/5; 216/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 5/5; 216/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.561 total time=   0.0s
# [CV 1/5; 217/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 1/5; 217/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 217/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 2/5; 217/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5; 217/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 3/5; 217/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 217/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 4/5; 217/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 217/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 5/5; 217/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 218/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 1/5; 218/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 218/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 2/5; 218/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 218/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 3/5; 218/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 218/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 4/5; 218/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 218/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 5/5; 218/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 219/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 1/5; 219/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 219/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 2/5; 219/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 219/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 3/5; 219/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 219/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 4/5; 219/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 5/5; 219/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 5/5; 219/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 220/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 1/5; 220/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 220/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 2/5; 220/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 220/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 3/5; 220/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 220/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 4/5; 220/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 220/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 5/5; 220/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 1/5; 221/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 1/5; 221/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 221/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 2/5; 221/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 221/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 3/5; 221/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 221/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 4/5; 221/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 256/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 4/5; 256/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 256/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 5/5; 256/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 2/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 2/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 3/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 3/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 3/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 4/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 260/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 260/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 260/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 260/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 2/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 4/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 5/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 3/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 4/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 1/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 202/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 2/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 202/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 3/5; 202/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 5/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 1/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 235/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 235/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 1/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 2/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 3/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 4/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 236/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 5/5; 236/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 1/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 1/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 2/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 3/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 4/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 5/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 1/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 2/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 3/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 4/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 5/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 1/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 2/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 3/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 4/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 5/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 3/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 4/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 271/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 1/5; 271/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 271/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 2/5; 271/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 1/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 1/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 2/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 5/5; 277/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 5/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 3/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 3/5; 257/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 3/5; 257/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 257/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 4/5; 257/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 1/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 261/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 261/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 4/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 4/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 2/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 3/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 268/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 4/5; 268/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.732 total time=   0.0s
# [CV 5/5; 268/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler()
# [CV 5/5; 268/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 5/5; 271/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler()
# [CV 5/5; 271/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=StandardScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 1/5; 272/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 274/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 2/5; 274/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5; 274/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 3/5; 274/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 2/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 2/5; 280/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 2/5; 280/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5; 280/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 3/5; 280/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 1/5; 283/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 1/5; 283/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 283/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 2/5; 283/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 5/5; 285/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 5/5; 285/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 1/288] START dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None
# [CV 2/5; 1/288] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 5/5; 1/288] START dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None
# [CV 5/5; 1/288] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=None;, score=nan total time=   0.0s
# [CV 5/5; 2/288] START dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 5/5; 2/288] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=StandardScaler();, score=nan total time=   0.0s
# [CV 2/5; 4/288] START dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 4/288] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# [CV 3/5; 4/288] START dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 4/288] END dim_reducer=None, model=LogisticRegression(max_iter=10000, n_jobs=-1, penalty='l1', random_state=1), model__C=1e-05, scaler=RobustScaler();, score=nan total time=   0.0s
# ...
# [CV 5/5; 193/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 5/5; 193/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 194/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 1/5; 194/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 194/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 2/5; 194/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 194/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 3/5; 194/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 194/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 4/5; 194/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 194/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 5/5; 194/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 195/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 1/5; 195/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 195/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 2/5; 195/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 195/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 3/5; 195/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 195/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 195/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 195/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 195/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 196/288] START dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 1/5; 196/288] END dim_reducer=PCA(), dim_reducer__n_components=0.95, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 5/5; 221/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 5/5; 221/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 222/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 1/5; 222/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 222/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 2/5; 222/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 222/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 3/5; 222/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 222/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 222/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 222/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 222/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 1/5; 223/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 1/5; 223/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 223/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 2/5; 223/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 223/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 3/5; 223/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 223/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 4/5; 223/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 223/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 5/5; 223/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 224/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 1/5; 224/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 224/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 224/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 224/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 224/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 224/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 4/5; 224/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 224/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 5/5; 224/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 225/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 1/5; 225/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 225/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 2/5; 225/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 225/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 3/5; 225/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 225/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 4/5; 225/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 225/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 5/5; 225/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 226/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 1/5; 226/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 226/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 2/5; 226/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 226/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 3/5; 226/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 226/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 4/5; 226/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 226/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 5/5; 226/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 227/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 1/5; 227/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 227/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 2/5; 227/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 227/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 3/5; 227/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.780 total time=   0.0s

# %% [markdown]
# ___
#
# ### Best Estimator
# Setting `verbose` to a number between 1 and 10 seems to be the most practical.
#
# We can now see what the best steps and hyperparameters were, using `.best_estimator_`:

# %%
fitted_logreg_gs.best_estimator_
# Out:
# Pipeline(memory='/var/folders/hd/c186n5_n3bz2nkrqf2gqjwlw0000gp/T/tmpjhy0rmr2',
#          steps=[('scaler', RobustScaler()), ('dim_reducer', None),
#                 ('model',
#                  LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1,
#                                     random_state=1))])

# %% [markdown]
# The best estimator used a robust scaler, no PCA, and a l2 logistic regression with a C value of 0.1. We can now evaluate this on the remainder and test sets.

# %%
# Print the accuracies
print(f"The best logistic regression's accuracy on the remainder set: {fitted_logreg_gs.score(X_rem, y_rem)}")
print(f"The best logistic regression's accuracy on the test set: {fitted_logreg_gs.score(X_test, y_test)}")
# Out:
# The best logistic regression's accuracy on the remainder set: 0.8695652173913043
# The best logistic regression's accuracy on the test set: 0.8555555555555555

# %%
# Reminder: baseline accuracies from before
print(f'Accuracy on remainder set: {baseline_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {baseline_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8444444444444444

# %%
# Reminder: one-validation accuracies from before
print(f'Accuracy on remainder set: {validated_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {validated_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8599033816425121
# Accuracy on test set: 0.8666666666666667

# %%
# Reminder: cross-validation accuracies from before
print(f'Accuracy on remainder set: {cv_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {cv_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8222222222222222

# %% [markdown]
# The test accuracy is better than all our previous models (except the one-validation).  Again, hyperparameter optimization does not guarantee that we will get the highest test accuracy, but it is still a good thing to do when building models.
#
# Optionally, we can now use joblib to pickle the best model for future use.

# %%
joblib.dump(fitted_logreg_gs.best_estimator_, 'data/pickles/pickled_best_logreg.pkl')
# Out:
# ['data/pickles/pickled_best_logreg.pkl']

# %%
# Sanity check on the pickled model
pickled_best_logreg = joblib.load('data/pickles/pickled_best_logreg.pkl')

# Print the accuracies
print(f"The best logistic regression's accuracy on the remainder set: {pickled_best_logreg.score(X_rem, y_rem)}")
print(f"The best logistic regression's accuracy on the test set: {pickled_best_logreg.score(X_test, y_test)}")
# Out:
# The best logistic regression's accuracy on the remainder set: 0.8695652173913043
# The best logistic regression's accuracy on the test set: 0.8555555555555555

# %% [markdown]
# Let's consider what happens to an object in our preprocessing:
#
# One of our steps was to scale the data, and we know that the best steps and hyperparameter of our best estimator used a `RobustScaler()`. When we are using `.score()` on the `X_test` data, what scaling properties will be used to transform the data?
#
#
# The scaler was fit using `X_rem` and our best estimator has that `RobustScaler()` object stored in memory which we can access:

# %%
best_scaler = pickled_best_logreg.get_params()['scaler']

# %%
print(type(best_scaler)) # sklearn.preprocessing._data.RobustScaler
print(best_scaler.get_params())
print(best_scaler.scale_)
# Out:
# <class 'sklearn.preprocessing._data.RobustScaler'>
# {'copy': True, 'quantile_range': (25.0, 75.0), 'unit_variance': False, 'with_centering': True, 'with_scaling': True}
# [13.   1.   1.  20.  60.5  1.   2.  28.5  1.   1.8  1.   1.   2. ]

# %%
test_scaler = RobustScaler()
# type(test_scaler) # sklearn.preprocessing._data.RobustScaler
test_scaler.get_params()
# test_scaler.scale_ # doesn't have yet so running this line causes an error
# we will get the .scale_ parameter after fitting the RobustScaler
# here we fit on X_rem
test_scaler.fit(X_rem)
# we can now see the RobustScaler's scale_ attribute
test_scaler.scale_
# Out:
# array([13. ,  1. ,  1. , 20. , 60.5,  1. ,  2. , 28.5,  1. ,  1.8,  1. ,
#         1. ,  2. ])

# %%
# we can check if our unpickled scaler has the same scale_ attribute as our newly created scaler
print(test_scaler.scale_ == best_scaler.scale_)
print(all(test_scaler.scale_ == best_scaler.scale_))
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# True

# %%
# here we fit a new scaler on X_test
test_scaler_control = RobustScaler().fit(X_test)
# we can see the attribute has different values to the scaler fitted on X_rem
test_scaler_control.scale_
# Out:
# array([14.25 ,  1.   ,  1.   , 20.   , 75.75 ,  1.   ,  2.   , 34.75 ,
#         1.   ,  1.575,  1.   ,  1.   ,  2.   ])

# %%
print(test_scaler_control == best_scaler.scale_)
print(all(test_scaler_control == best_scaler.scale_))
# Out:
# [False False False False False False False False False False False False
#  False]
# False

# %% [markdown]
# ___
# ### Conclusions and Common Questions
# 1. By using a pipeline and grid search, we can properly and easily do scaling and PCA on all the folds.

# %% [markdown]
# 2. Scaling and PCA are not guaranteed to improve model performance.

# %% [markdown]
# 3. Question:
# >After fitting a scaler on the train set, then transforming the train, validation, and test sets, and after finding the optimal hyperparameters, how do we scale the remainder (train + validation) set? Do we use the scaler that we fit on the train set to transform the remainder set? Do we refit the scaler to the remainder set? Do we combine the scaled train and validation sets?
#
#     Although I don't know a clear answer to this, what happens in the case of a cross-validated grid search is that the scaler gets refit to the remainder set in the best estimator. Read about the `refit` parameter here: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# 4. From the hyperparameter optimization lecture:
# >If we used any other models (KNN, Decision Tree, etc.) to try and compare performance, we have to use the same training and validation set to tune the hyperparameters of each model and get a final accuracy on the exact same test set. This is the fair way to compare performance between different models.
#
#     Would we be violating this by building a grid search for each model type? I don't think so. `GridSearchCV()` also uses `StratifiedKFold()` which does not shuffle the data points by default (which is okay because they were shuffled in `train_test_split`), so the folds would be the same for all grid searches. Even if this isn't the case, this isn't much of an issue because cross-validation averages out the scores anyway.

# %% [markdown]
# 5. The downside of using grid search is that we can't easily see a trend to determine what other range of hyperparameters we should try, or where we might be overfitting to the train set (although theoretically, cross-validation combats this). However, `GridSearchCV()` does have a parameter called `return_train_score`, which is set to `False` by default. Here's the documentation for it if you're curious:
# >If `False`, the `cv_results_` attribute will not include training scores. Computing training scores is used to get insights on how different parameter settings impact the overfitting/underfitting trade-off. However computing the scores on the training set can be computationally expensive and is not strictly required to select the parameters that yield the best generalization performance.

# %% [markdown]
# 6. The random state that we choose when performing our splits can have a big impact on our baseline models accuracy.

# %%
# Split the data into remainder and test sets
# X_rem, X_test, y_rem, y_test = train_test_split(X, y, test_size=0.3, random_state=22, stratify=y)
# X_rem, X_test, y_rem, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
# X_rem, X_test, y_rem, y_test = train_test_split(X, y, test_size=0.3, random_state=99, stratify=y)
X_rem, X_test, y_rem, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# Print info on how the data has been split
print(f'The remainder set has {len(X_rem)} data points.')
print(f'The test set has {len(X_test)} data points.')
# Out:
# The remainder set has 207 data points.
# The test set has 90 data points.

# %%
# Baseline logistic regression
# Instantiate and fit to the remainder set
baseline_logreg = LogisticRegression(random_state=1).fit(X_rem, y_rem)

# Print the accuracies
print(f'Accuracy on remainder set: {baseline_logreg.score(X_rem, y_rem)}')
print(f'Accuracy on test set: {baseline_logreg.score(X_test, y_test)}')
# Out:
# Accuracy on remainder set: 0.8695652173913043
# Accuracy on test set: 0.8222222222222222
# [CV 2/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 3/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 4/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 232/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 232/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 3/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 233/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 233/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 1/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 2/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 234/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 234/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 3/5; 263/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 3/5; 263/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 263/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler()
# [CV 4/5; 263/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 2/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 3/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 3/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 4/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 2/5; 272/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 3/5; 272/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.732 total time=   0.0s
# [CV 1/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 1/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 2/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 2/5; 282/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 2/5; 282/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.786 total time=   0.0s
# [CV 3/5; 282/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 3/5; 282/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 285/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 5/5; 285/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 237/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 237/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 1/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 2/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 3/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 4/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 238/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 5/5; 238/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 1/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 2/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 3/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 4/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 239/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 5/5; 239/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 1/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 2/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 3/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 4/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 240/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 5/5; 240/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 4/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 258/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 5/5; 258/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 4/5; 260/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 4/5; 260/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 260/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 5/5; 260/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 2/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 2/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 262/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler()
# [CV 3/5; 262/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 2/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 2/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 3/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 3/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 1/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 2/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 270/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 2/5; 270/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 3/5; 270/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 3/5; 270/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 273/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 3/5; 273/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 273/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 4/5; 273/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 2/5; 276/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 2/5; 276/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.786 total time=   0.0s
# [CV 3/5; 276/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 3/5; 276/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 279/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 1/5; 279/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 279/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 2/5; 279/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.786 total time=   0.0s
# [CV 3/5; 281/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 3/5; 281/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 4/5; 281/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 4/5; 281/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 2/5; 284/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 2/5; 284/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 284/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler()
# [CV 3/5; 284/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 1/5; 287/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 1/5; 287/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 287/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler()
# [CV 2/5; 287/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=MinMaxScaler();, score=0.881 total time=   0.0s
# [CV 4/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 249/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 249/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 1/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 2/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 3/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 4/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 250/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler()
# [CV 5/5; 250/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 1/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 2/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 3/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 4/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 251/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 5/5; 251/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 1/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 2/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 3/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 4/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 252/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 5/5; 252/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 253/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 1/5; 253/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 253/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 2/5; 253/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 253/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 3/5; 253/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 253/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 4/5; 253/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 279/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 5/5; 279/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 280/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 1/5; 280/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 3/5; 283/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 3/5; 283/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 283/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 4/5; 283/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 4/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 5/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.854 total time=   0.0s
# [CV 2/5; 168/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 2/5; 168/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 3/5; 168/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 3/5; 168/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 168/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 4/5; 168/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 168/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 5/5; 168/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 1/5; 169/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None
# [CV 1/5; 169/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None;, score=0.881 total time=   0.1s
# [CV 2/5; 169/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None
# [CV 2/5; 169/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None;, score=0.810 total time=   0.1s
# [CV 3/5; 169/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None
# [CV 3/5; 169/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None;, score=0.780 total time=   0.1s
# [CV 4/5; 169/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None
# [CV 4/5; 169/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None;, score=0.805 total time=   0.1s
# [CV 5/5; 169/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None
# [CV 5/5; 169/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=None;, score=0.805 total time=   0.1s
# [CV 1/5; 170/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 1/5; 170/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.881 total time=   0.0s
# [CV 2/5; 170/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 2/5; 170/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.810 total time=   0.0s
# [CV 3/5; 170/288] START dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 3/5; 170/288] END dim_reducer=None, model=LogisticRegression(C=0.1, max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 5/5; 253/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler()
# [CV 5/5; 253/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=StandardScaler();, score=0.780 total time=   0.0s
# [CV 1/5; 254/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 1/5; 254/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 2/5; 254/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 2/5; 254/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.857 total time=   0.0s
# [CV 3/5; 254/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 3/5; 254/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 254/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 4/5; 254/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 254/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 5/5; 254/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 255/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 1/5; 255/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 255/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 2/5; 255/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 255/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 3/5; 255/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 255/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 4/5; 255/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 255/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 5/5; 255/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 256/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 1/5; 256/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 256/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 2/5; 256/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 256/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler()
# [CV 3/5; 256/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=StandardScaler();, score=0.829 total time=   0.0s
# ...
# [CV 1/5; 247/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 247/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler()
# [CV 2/5; 247/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 5/5; 265/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler()
# [CV 5/5; 265/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=StandardScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 266/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler()
# [CV 1/5; 266/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 1/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 1/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 2/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 2/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.548 total time=   0.0s
# [CV 4/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 4/5; 272/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 272/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler()
# [CV 5/5; 272/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 3/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 3/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 275/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler()
# [CV 4/5; 275/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=MinMaxScaler();, score=0.780 total time=   0.0s
# [CV 4/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 4/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.756 total time=   0.0s
# [CV 5/5; 278/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler()
# [CV 5/5; 278/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 5/5; 281/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 5/5; 281/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.878 total time=   0.0s
# [CV 1/5; 282/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 1/5; 282/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.881 total time=   0.0s
# [CV 3/5; 285/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 3/5; 285/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 285/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler()
# [CV 4/5; 285/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 288/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 288/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 288/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 5/5; 288/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 227/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 4/5; 227/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.805 total time=   0.0s
# [CV 5/5; 227/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler()
# [CV 5/5; 227/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=MinMaxScaler();, score=0.854 total time=   0.0s
# [CV 1/5; 228/288] START dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 1/5; 228/288] END dim_reducer=PCA(), dim_reducer__n_components=0.9, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.857 total time=   0.0s
# [CV 1/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 1/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 259/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 259/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.905 total time=   0.0s
# [CV 3/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 3/5; 261/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 261/288] START dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler()
# [CV 4/5; 261/288] END dim_reducer=PCA(), dim_reducer__n_components=0.85, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 4/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 264/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler()
# [CV 5/5; 264/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1e-05, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 3/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 3/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 4/5; 267/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler()
# [CV 4/5; 267/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.0001, scaler=RobustScaler();, score=0.537 total time=   0.0s
# [CV 5/5; 269/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler()
# [CV 5/5; 269/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=MinMaxScaler();, score=0.537 total time=   0.0s
# [CV 1/5; 270/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler()
# [CV 1/5; 270/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.001, scaler=RobustScaler();, score=0.595 total time=   0.0s
# [CV 1/5; 273/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 1/5; 273/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.833 total time=   0.0s
# [CV 2/5; 273/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler()
# [CV 2/5; 273/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=0.1, scaler=RobustScaler();, score=0.762 total time=   0.0s
# [CV 4/5; 276/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 4/5; 276/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 276/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler()
# [CV 5/5; 276/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=1, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 3/5; 279/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 3/5; 279/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 4/5; 279/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler()
# [CV 4/5; 279/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 4/5; 282/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 4/5; 282/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.829 total time=   0.0s
# [CV 5/5; 282/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler()
# [CV 5/5; 282/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=100, scaler=RobustScaler();, score=0.805 total time=   0.0s
# [CV 2/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 2/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.929 total time=   0.0s
# [CV 3/5; 286/288] START dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler()
# [CV 3/5; 286/288] END dim_reducer=PCA(), dim_reducer__n_components=0.8, model=LogisticRegression(max_iter=10000, n_jobs=-1, random_state=1), model__C=10000, scaler=StandardScaler();, score=0.829 total time=   0.0s
